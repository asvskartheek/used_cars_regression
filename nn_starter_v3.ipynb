# %%
VERSION = 3

# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt

train = pd.read_csv("data/train.csv") 
print("Train shape:", train.shape )
TRAIN_LN = len(train)
display( train.head(1) )

test = pd.read_csv("data/test.csv") 
test['price'] = 0
print("Test shape:", test.shape )
display( test.head(1) )

train = pd.concat([train,test],axis=0,ignore_index=True)
print("Combined shape:", train.shape )
# Out:
# Train shape: (188533, 13)
#    id brand          model  model_year  milage fuel_type  \
# 0   0  MINI  Cooper S Base        2007  213000  Gasoline
#
#                                          engine transmission ext_col int_col  \
# 0  172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel          A/T  Yellow    Gray
#
#         accident clean_title  price
# 0  None reported         Yes   4200
# Test shape: (125690, 13)
#        id brand           model  model_year  milage fuel_type  \
# 0  188533  Land  Rover LR2 Base        2015   98000  Gasoline
#
#                                          engine transmission ext_col int_col  \
# 0  240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel  6-Speed A/T   White   Beige
#
#         accident clean_title  price
# 0  None reported         Yes      0
# Combined shape: (314223, 13)

# %%
CATS = [c for c in train.columns if not c in ["id","price"] ]
NUMS = ['milage']
CATS = [c for c in CATS if not c in NUMS]
print("Categorical features:", CATS )
print("Numerical features:", NUMS)
# Out:
# Categorical features: ['brand', 'model', 'model_year', 'fuel_type', 'engine', 'transmission', 'ext_col', 'int_col', 'accident', 'clean_title']
# Numerical features: ['milage']

# %%
print("STANDARDIZING NUMERICAL FEATURES")
for c in NUMS:
    m = train[c].mean()
    s = train[c].std()
    train[c] = (train[c]-m)/s
    train[c] = train[c].fillna(m)
    print(f"{c}, new_mean={train[c].mean():.2f}, new_std={train[c].std():.2f}")
# Out:
# STANDARDIZING NUMERICAL FEATURES
# milage, new_mean=-0.00, new_std=1.00

# %%
cat_feature_sizes = []
cat_embedding_sizes = []
rare_cat_lists = []
MIN_CATEGORY_COUNT = 40

print("Label Encoding Categorical Features:")
for cat_feature in CATS:
    train[cat_feature], _ = train[cat_feature].factorize()
    train[cat_feature] -= train[cat_feature].min() # We are doing this to ensure that the encoded values start from 0, ensuring a consistent range for all categorical features.
    value_counts = train[cat_feature].value_counts().to_dict()
    
    # Identify rare categories
    rare_cat_lists.append([
        value
        for value, count in value_counts.items()
        if count < MIN_CATEGORY_COUNT
    ])
    unique_count = train[cat_feature].nunique()
    min_freq = train[cat_feature].min()
    max_freq = train[cat_feature].max()
    rare_count = len(rare_cat_lists[-1])
    print(f'{cat_feature}: unique={unique_count}, min_freq={min_freq}, max_freq={max_freq}, rare_count={rare_count}')
    
    # Adjust category encoding
    cat_feature_sizes.append(max_freq + 2)  # +2 for rare category (0) and zero-indexing (1 to max_freq+1). This ensures we have enough space for all categories, including the rare ones grouped together.
    cat_embedding_sizes.append(int(np.ceil(np.sqrt(max_freq + 2)))) # TODO: Find a reference for this formula. Got this snippet from https://www.kaggle.com/code/cdeotte/nn-starter-lb-72300-cv-72800
    train[cat_feature] += 1
    train.loc[train[cat_feature].isin(rare_cat_lists[-1]), cat_feature] = 0 # rare_cat_lists[-1] gives the list of rare categories for the current feature
# Out:
# Label Encoding Categorical Features:
# brand: unique=57, min_freq=0, max_freq=56, rare_count=8
# model: unique=1898, min_freq=0, max_freq=1897, rare_count=551
# model_year: unique=36, min_freq=0, max_freq=35, rare_count=4
# fuel_type: unique=8, min_freq=0, max_freq=7, rare_count=1
# engine: unique=1118, min_freq=0, max_freq=1117, rare_count=308
# transmission: unique=52, min_freq=0, max_freq=51, rare_count=8
# ext_col: unique=319, min_freq=0, max_freq=318, rare_count=99
# int_col: unique=156, min_freq=0, max_freq=155, rare_count=48
# accident: unique=3, min_freq=0, max_freq=2, rare_count=0
# clean_title: unique=2, min_freq=0, max_freq=1, rare_count=0

# %%
test = train.iloc[TRAIN_LN:]
train = train.iloc[:TRAIN_LN]
train.shape, test.shape
# Out:
# ((188533, 13), (125690, 13))

# %%
for feature in CATS:
    train_categories = train[feature].unique()
    test_categories = test[feature].unique()
    unseen_categories = np.setdiff1d(test_categories, train_categories)
    print(f"{feature}: Test has label encodes = {unseen_categories} which are not in train.")
    if len(unseen_categories) > 0:
        unseen_rows_count = len(test.loc[test[feature].isin(unseen_categories)])
        print(f" => {unseen_rows_count} rows")
    
    test.loc[test[feature].isin(unseen_categories), feature] = 0
# Out:
# brand: Test has label encodes = [] which are not in train.
# model: Test has label encodes = [1898] which are not in train.
#  => 1 rows
# model_year: Test has label encodes = [36] which are not in train.
#  => 1 rows
# fuel_type: Test has label encodes = [] which are not in train.
# engine: Test has label encodes = [1118] which are not in train.
#  => 4 rows
# transmission: Test has label encodes = [] which are not in train.
# ext_col: Test has label encodes = [] which are not in train.
# int_col: Test has label encodes = [] which are not in train.
# accident: Test has label encodes = [] which are not in train.
# clean_title: Test has label encodes = [] which are not in train.

# %%
from sklearn.model_selection import KFold
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, Input, Embedding
from tensorflow.keras.layers import Concatenate, Multiply
import tensorflow.keras.backend as K

print('TF Version',tf.__version__)
# Out:
# TF Version 2.16.1

# %%
EPOCHS = 10
LRS = [0.001]*3 + [0.0005]*3 + [0.0001]*3 + [0.00005]*1

def lrfn(epoch):
    return LRS[epoch]

rng = [i for i in range(EPOCHS)]
lr_y = [lrfn(x) for x in rng]
plt.figure(figsize=(10, 4))
plt.plot(rng, lr_y, '-o')
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}". \
        format(lr_y[0], max(lr_y), lr_y[-1]))
plt.xlabel("Epoch")
plt.ylabel("Learning Rate")
plt.title("Learning Rate Schedule")
plt.show()

lr_callback = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose = True)
# Out:
# Learning rate schedule: 0.001 to 0.001 to 5e-05

# %%
def build_model():
    # CATEGORICAL FEATURES
    x_input_cats = Input(shape=(len(CATS),))
    embs = []
    for j in range(len(CATS)):
        e = tf.keras.layers.Embedding(cat_feature_sizes[j],cat_embedding_sizes[j])
        x = e(x_input_cats[:,j])
        x = tf.keras.layers.Flatten()(x)
        embs.append(x)
        
    # NUMERICAL FEATURES
    x_input_nums = Input(shape=(len(NUMS),))
    
    # COMBINE
    x = tf.keras.layers.Concatenate(axis=-1)(embs+[x_input_nums]) 
    x = Dense(256, activation='relu')(x)
    x = Dense(256, activation='relu')(x)
    x = Dense(256, activation='relu')(x)
    x = Dense(1, activation='linear')(x)
    
    model = Model(inputs=[x_input_cats,x_input_nums], outputs=x)
    
    return model

# %%
import os

NUM_FOLDS = 5
RANDOM_STATE = 42
MODEL_CHECKPOINT_DIR = f"checkpoints/"
MODEL_CHECKPOINT_FILE = f"NN_{VERSION}.weights.h5"
TENSOREBOARD_LOG_DIR = f"tensorboard_logs/version_{VERSION}"

kf = KFold(n_splits=NUM_FOLDS, random_state=RANDOM_STATE, shuffle=True)

out_of_fold_predictions = np.zeros(len(train))
test_predictions = np.zeros(len(test))

# Create directory for model checkpoints
if not os.path.exists(MODEL_CHECKPOINT_DIR):
    os.makedirs(MODEL_CHECKPOINT_DIR)

# Create directory for TensorBoard logs
if not os.path.exists(TENSOREBOARD_LOG_DIR):
    os.makedirs(TENSOREBOARD_LOG_DIR)

for fold, (train_index, val_index) in enumerate(kf.split(train), 1):
    print("#" * 25)
    print(f"### Fold {fold} ###")
    print("#" * 25)

    # Prepare data for current fold
    X_train_cats = train.loc[train_index, CATS].values
    X_train_nums = train.loc[train_index, NUMS].values
    y_train = train.loc[train_index, "price"].values
    
    X_val_cats = train.loc[val_index, CATS].values
    X_val_nums = train.loc[val_index, NUMS].values
    y_val = train.loc[val_index, "price"].values
    
    X_test_cats = test[CATS].values
    X_test_nums = test[NUMS].values
    
    # Train model
    K.clear_session()
    model = build_model()
    model.compile(optimizer=tf.keras.optimizers.Adam(0.001), 
                  loss="mean_squared_error", 
                  metrics=[tf.keras.metrics.RootMeanSquaredError()])
    
    # Create TensorBoard callback
    tensorboard_callback = tf.keras.callbacks.TensorBoard(
        log_dir=f"{TENSOREBOARD_LOG_DIR}/fold_{fold}",
        histogram_freq=1,
        write_graph=True,
        write_images=True,
        update_freq='epoch',
        profile_batch=0
    )
    
    model.fit([X_train_cats, X_train_nums], y_train, 
              validation_data=([X_val_cats, X_val_nums], y_val),
              callbacks=[lr_callback, tensorboard_callback],
              batch_size=64, epochs=EPOCHS, verbose=2)
    
    # Save model weights
    model.save_weights(f'{MODEL_CHECKPOINT_DIR}/{MODEL_CHECKPOINT_FILE}')
    
    # Make predictions on validation set
    val_predictions = model.predict([X_val_cats, X_val_nums], verbose=1, batch_size=512).flatten()
    rmse = np.sqrt(np.mean((val_predictions - y_val)**2))
    print(f' => RMSE = {rmse}\n')
    
    # Store out-of-fold predictions
    out_of_fold_predictions[val_index] = val_predictions
    
    # Make predictions on test set
    fold_test_predictions = model.predict([X_test_cats, X_test_nums], verbose=1, batch_size=512).flatten()
    test_predictions += fold_test_predictions

# Average test predictions across all folds
test_predictions /= NUM_FOLDS
# Out:
# #########################
# ### Fold 1 ###
# #########################
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.001.
# Epoch 1/10
# 2357/2357 - 6s - 2ms/step - loss: 5684666880.0000 - root_mean_squared_error: 75396.7266 - val_loss: 4648890368.0000 - val_root_mean_squared_error: 68182.7734 - learning_rate: 0.0010
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.001.
# Epoch 2/10
# 2357/2357 - 5s - 2ms/step - loss: 5443370496.0000 - root_mean_squared_error: 73779.2031 - val_loss: 4654124032.0000 - val_root_mean_squared_error: 68221.1406 - learning_rate: 0.0010
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.001.
# Epoch 3/10
# 2357/2357 - 5s - 2ms/step - loss: 5405243392.0000 - root_mean_squared_error: 73520.3594 - val_loss: 4640425984.0000 - val_root_mean_squared_error: 68120.6719 - learning_rate: 0.0010
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0005.
# Epoch 4/10
# 2357/2357 - 5s - 2ms/step - loss: 5359107072.0000 - root_mean_squared_error: 73205.9219 - val_loss: 4632197632.0000 - val_root_mean_squared_error: 68060.2500 - learning_rate: 5.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0005.
# Epoch 5/10
# 2357/2357 - 5s - 2ms/step - loss: 5340268544.0000 - root_mean_squared_error: 73077.1406 - val_loss: 4642228224.0000 - val_root_mean_squared_error: 68133.8984 - learning_rate: 5.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0005.
# Epoch 6/10
# 2357/2357 - 5s - 2ms/step - loss: 5324793344.0000 - root_mean_squared_error: 72971.1797 - val_loss: 4667333120.0000 - val_root_mean_squared_error: 68317.8828 - learning_rate: 5.0000e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 7/10
# 2357/2357 - 5s - 2ms/step - loss: 5280969216.0000 - root_mean_squared_error: 72670.2812 - val_loss: 4650440192.0000 - val_root_mean_squared_error: 68194.1328 - learning_rate: 1.0000e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 8/10
# 2357/2357 - 5s - 2ms/step - loss: 5274937344.0000 - root_mean_squared_error: 72628.7656 - val_loss: 4652785152.0000 - val_root_mean_squared_error: 68211.3281 - learning_rate: 1.0000e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 9/10
# 2357/2357 - 5s - 2ms/step - loss: 5268248064.0000 - root_mean_squared_error: 72582.6953 - val_loss: 4665216512.0000 - val_root_mean_squared_error: 68302.3906 - learning_rate: 1.0000e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 5e-05.
# Epoch 10/10
# 2357/2357 - 5s - 2ms/step - loss: 5259398144.0000 - root_mean_squared_error: 72521.7109 - val_loss: 4663949824.0000 - val_root_mean_squared_error: 68293.1172 - learning_rate: 5.0000e-05
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
#  => RMSE = 68293.10948841016
#
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# #########################
# ### Fold 2 ###
# #########################
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.001.
# Epoch 1/10
# 2357/2357 - 6s - 3ms/step - loss: 5657783808.0000 - root_mean_squared_error: 75218.2422 - val_loss: 4741336576.0000 - val_root_mean_squared_error: 68857.3672 - learning_rate: 0.0010
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.001.
# Epoch 2/10
# 2357/2357 - 5s - 2ms/step - loss: 5415825408.0000 - root_mean_squared_error: 73592.2891 - val_loss: 4778498560.0000 - val_root_mean_squared_error: 69126.6875 - learning_rate: 0.0010
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.001.
# Epoch 3/10
# 2357/2357 - 5s - 2ms/step - loss: 5378904064.0000 - root_mean_squared_error: 73341.0156 - val_loss: 4726194688.0000 - val_root_mean_squared_error: 68747.3281 - learning_rate: 0.0010
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0005.
# Epoch 4/10
# 2357/2357 - 5s - 2ms/step - loss: 5331816448.0000 - root_mean_squared_error: 73019.2891 - val_loss: 4732262400.0000 - val_root_mean_squared_error: 68791.4375 - learning_rate: 5.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0005.
# Epoch 5/10
# 2357/2357 - 5s - 2ms/step - loss: 5313010176.0000 - root_mean_squared_error: 72890.3984 - val_loss: 4737057792.0000 - val_root_mean_squared_error: 68826.2891 - learning_rate: 5.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0005.
# Epoch 6/10
# 2357/2357 - 5s - 2ms/step - loss: 5301272576.0000 - root_mean_squared_error: 72809.8359 - val_loss: 4741143040.0000 - val_root_mean_squared_error: 68855.9609 - learning_rate: 5.0000e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 7/10
# 2357/2357 - 5s - 2ms/step - loss: 5255887360.0000 - root_mean_squared_error: 72497.5000 - val_loss: 4766984192.0000 - val_root_mean_squared_error: 69043.3516 - learning_rate: 1.0000e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 8/10
# 2357/2357 - 5s - 2ms/step - loss: 5249764352.0000 - root_mean_squared_error: 72455.2578 - val_loss: 4761944576.0000 - val_root_mean_squared_error: 69006.8438 - learning_rate: 1.0000e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 9/10
# 2357/2357 - 5s - 2ms/step - loss: 5245080576.0000 - root_mean_squared_error: 72422.9297 - val_loss: 4776351232.0000 - val_root_mean_squared_error: 69111.1484 - learning_rate: 1.0000e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 5e-05.
# Epoch 10/10
# 2357/2357 - 5s - 2ms/step - loss: 5236657152.0000 - root_mean_squared_error: 72364.7500 - val_loss: 4776868352.0000 - val_root_mean_squared_error: 69114.8906 - learning_rate: 5.0000e-05
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#  => RMSE = 69114.88931599053
#
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# #########################
# ### Fold 3 ###
# #########################
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.001.
# Epoch 1/10
# 2357/2357 - 7s - 3ms/step - loss: 5486274048.0000 - root_mean_squared_error: 74069.3828 - val_loss: 5481398784.0000 - val_root_mean_squared_error: 74036.4688 - learning_rate: 0.0010
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.001.
# Epoch 2/10
# 2357/2357 - 5s - 2ms/step - loss: 5239761920.0000 - root_mean_squared_error: 72386.2031 - val_loss: 5488501760.0000 - val_root_mean_squared_error: 74084.4219 - learning_rate: 0.0010
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.001.
# Epoch 3/10
# 2357/2357 - 6s - 2ms/step - loss: 5201340416.0000 - root_mean_squared_error: 72120.3203 - val_loss: 5478647808.0000 - val_root_mean_squared_error: 74017.8906 - learning_rate: 0.0010
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0005.
# Epoch 4/10
# 2357/2357 - 5s - 2ms/step - loss: 5149677056.0000 - root_mean_squared_error: 71761.2500 - val_loss: 5482739712.0000 - val_root_mean_squared_error: 74045.5234 - learning_rate: 5.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0005.
# Epoch 5/10
# 2357/2357 - 5s - 2ms/step - loss: 5133388800.0000 - root_mean_squared_error: 71647.6719 - val_loss: 5489721856.0000 - val_root_mean_squared_error: 74092.6562 - learning_rate: 5.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0005.
# Epoch 6/10
# 2357/2357 - 5s - 2ms/step - loss: 5117745664.0000 - root_mean_squared_error: 71538.4219 - val_loss: 5494659072.0000 - val_root_mean_squared_error: 74125.9688 - learning_rate: 5.0000e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 7/10
# 2357/2357 - 5s - 2ms/step - loss: 5074021376.0000 - root_mean_squared_error: 71232.1641 - val_loss: 5520401920.0000 - val_root_mean_squared_error: 74299.4062 - learning_rate: 1.0000e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 8/10
# 2357/2357 - 5s - 2ms/step - loss: 5067464704.0000 - root_mean_squared_error: 71186.1250 - val_loss: 5526200832.0000 - val_root_mean_squared_error: 74338.4219 - learning_rate: 1.0000e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 9/10
# 2357/2357 - 5s - 2ms/step - loss: 5062418432.0000 - root_mean_squared_error: 71150.6719 - val_loss: 5528572416.0000 - val_root_mean_squared_error: 74354.3672 - learning_rate: 1.0000e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 5e-05.
# Epoch 10/10
# 2357/2357 - 5s - 2ms/step - loss: 5052038656.0000 - root_mean_squared_error: 71077.6953 - val_loss: 5525152768.0000 - val_root_mean_squared_error: 74331.3750 - learning_rate: 5.0000e-05
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#  => RMSE = 74331.3771766988
#
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# #########################
# ### Fold 4 ###
# #########################
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.001.
# Epoch 1/10
# 2357/2357 - 6s - 2ms/step - loss: 5340519424.0000 - root_mean_squared_error: 73078.8594 - val_loss: 5872107008.0000 - val_root_mean_squared_error: 76629.6719 - learning_rate: 0.0010
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.001.
# Epoch 2/10
# 2357/2357 - 4s - 2ms/step - loss: 5140108288.0000 - root_mean_squared_error: 71694.5469 - val_loss: 5853576192.0000 - val_root_mean_squared_error: 76508.6641 - learning_rate: 0.0010
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.001.
# Epoch 3/10
# 2357/2357 - 5s - 2ms/step - loss: 5107511808.0000 - root_mean_squared_error: 71466.8594 - val_loss: 5855895552.0000 - val_root_mean_squared_error: 76523.8203 - learning_rate: 0.0010
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0005.
# Epoch 4/10
# 2357/2357 - 5s - 2ms/step - loss: 5058295808.0000 - root_mean_squared_error: 71121.6953 - val_loss: 5865779200.0000 - val_root_mean_squared_error: 76588.3750 - learning_rate: 5.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0005.
# Epoch 5/10
# 2357/2357 - 4s - 2ms/step - loss: 5044216320.0000 - root_mean_squared_error: 71022.6484 - val_loss: 5862236672.0000 - val_root_mean_squared_error: 76565.2422 - learning_rate: 5.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0005.
# Epoch 6/10
# 2357/2357 - 4s - 2ms/step - loss: 5028916224.0000 - root_mean_squared_error: 70914.8516 - val_loss: 5899342336.0000 - val_root_mean_squared_error: 76807.1797 - learning_rate: 5.0000e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 7/10
# 2357/2357 - 5s - 2ms/step - loss: 4989208576.0000 - root_mean_squared_error: 70634.3281 - val_loss: 5877283328.0000 - val_root_mean_squared_error: 76663.4453 - learning_rate: 1.0000e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 8/10
# 2357/2357 - 5s - 2ms/step - loss: 4985290240.0000 - root_mean_squared_error: 70606.5859 - val_loss: 5884768256.0000 - val_root_mean_squared_error: 76712.2422 - learning_rate: 1.0000e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 9/10
# 2357/2357 - 4s - 2ms/step - loss: 4980341760.0000 - root_mean_squared_error: 70571.5391 - val_loss: 5896264192.0000 - val_root_mean_squared_error: 76787.1328 - learning_rate: 1.0000e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 5e-05.
# Epoch 10/10
# 2357/2357 - 5s - 2ms/step - loss: 4972407808.0000 - root_mean_squared_error: 70515.3047 - val_loss: 5894118400.0000 - val_root_mean_squared_error: 76773.1641 - learning_rate: 5.0000e-05
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#  => RMSE = 76773.17758383731
#
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# #########################
# ### Fold 5 ###
# #########################
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.001.
# Epoch 1/10
# 2357/2357 - 6s - 2ms/step - loss: 5376580608.0000 - root_mean_squared_error: 73325.1719 - val_loss: 5837207040.0000 - val_root_mean_squared_error: 76401.6172 - learning_rate: 0.0010
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.001.
# Epoch 2/10
# 2357/2357 - 6s - 2ms/step - loss: 5153740288.0000 - root_mean_squared_error: 71789.5547 - val_loss: 5815558144.0000 - val_root_mean_squared_error: 76259.8047 - learning_rate: 0.0010
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.001.
# Epoch 3/10
# 2357/2357 - 5s - 2ms/step - loss: 5109484544.0000 - root_mean_squared_error: 71480.6562 - val_loss: 5814212608.0000 - val_root_mean_squared_error: 76250.9844 - learning_rate: 0.0010
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0005.
# Epoch 4/10
# 2357/2357 - 5s - 2ms/step - loss: 5056738816.0000 - root_mean_squared_error: 71110.7500 - val_loss: 5825551872.0000 - val_root_mean_squared_error: 76325.3047 - learning_rate: 5.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0005.
# Epoch 5/10
# 2357/2357 - 5s - 2ms/step - loss: 5041714688.0000 - root_mean_squared_error: 71005.0312 - val_loss: 5837432832.0000 - val_root_mean_squared_error: 76403.0938 - learning_rate: 5.0000e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0005.
# Epoch 6/10
# 2357/2357 - 5s - 2ms/step - loss: 5027004928.0000 - root_mean_squared_error: 70901.3750 - val_loss: 5836017664.0000 - val_root_mean_squared_error: 76393.8359 - learning_rate: 5.0000e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 7/10
# 2357/2357 - 5s - 2ms/step - loss: 4984778240.0000 - root_mean_squared_error: 70602.9609 - val_loss: 5840640512.0000 - val_root_mean_squared_error: 76424.0859 - learning_rate: 1.0000e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 8/10
# 2357/2357 - 6s - 2ms/step - loss: 4978902016.0000 - root_mean_squared_error: 70561.3359 - val_loss: 5849175040.0000 - val_root_mean_squared_error: 76479.8984 - learning_rate: 1.0000e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 9/10
# 2357/2357 - 5s - 2ms/step - loss: 4972730880.0000 - root_mean_squared_error: 70517.5938 - val_loss: 5848816640.0000 - val_root_mean_squared_error: 76477.5547 - learning_rate: 1.0000e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 5e-05.
# Epoch 10/10
# 2357/2357 - 5s - 2ms/step - loss: 4964644352.0000 - root_mean_squared_error: 70460.2344 - val_loss: 5855055360.0000 - val_root_mean_squared_error: 76518.3359 - learning_rate: 5.0000e-05
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#  => RMSE = 76518.32830623523
#
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
# COMPUTE AND DISPLAY CV RSME SCORE
rsme = np.sqrt(np.mean( (out_of_fold_predictions-train.price.values)**2 ))
print("Overall CV RSME =",rsme)

# SAVE OOF 
oof_df = train[["id"]].copy()
oof_df["pred"] = out_of_fold_predictions
oof_df.to_csv(f"predictions/oof_v{VERSION}.csv",index=False)
# Out:
# Overall CV RSME = 73095.98830358137

# %%
sub = pd.read_csv("data/sample_submission.csv")
sub.price = test_predictions
print("Submission shape:",sub.shape)
sub.to_csv(f"predictions/submission_v{VERSION}.csv",index=False)
sub.head()
# Out:
# Submission shape: (125690, 2)
#        id         price
# 0  188533  16268.362695
# 1  188534  66159.289844
# 2  188535  55587.291406
# 3  188536  24639.276562
# 4  188537  28815.024609
